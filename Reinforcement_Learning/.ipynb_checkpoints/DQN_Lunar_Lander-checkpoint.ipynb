# %%
import gymnasium as gym
import numpy as np
import random
from collections import deque

import torch
import torch.nn as nn
import torch.optim as optim

# %%
# ======================
# Hyperparameters
# ======================
ENV_NAME = "LunarLander-v3"
GAMMA = 0.99
LR = 1e-3
BATCH_SIZE = 64
BUFFER_SIZE = 100_000
MIN_REPLAY_SIZE = 1_000
TAU = 0.01                   # soft update rate
EPS_START = 1.0
EPS_END = 0.01
EPS_DECAY = 0.995
NUM_EPISODES = 200
MAX_STEPS = 1000

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# ======================
# Q-Network
# ======================
class QNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim)
        )

    def forward(self, x):
        return self.net(x)

# %%
# ======================
# Replay Buffer
# ======================
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def add(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        return (
            torch.tensor(states, dtype=torch.float32, device=device),
            torch.tensor(actions, dtype=torch.int64, device=device),
            torch.tensor(rewards, dtype=torch.float32, device=device),
            torch.tensor(next_states, dtype=torch.float32, device=device),
            torch.tensor(dones, dtype=torch.float32, device=device),
        )

    def __len__(self):
        return len(self.buffer)

# %%
# ======================
# Epsilon-Greedy Policy
# ======================
def select_action(state, q_net, epsilon, action_dim):
    if random.random() < epsilon:
        return random.randrange(action_dim)
    else:
        state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        with torch.no_grad():
            q_values = q_net(state)
        return torch.argmax(q_values).item()

# %%
# ======================
# Training Step
# ======================
def train_step(q_net, target_net, optimizer, replay_buffer):
    states, actions, rewards, next_states, dones = replay_buffer.sample(BATCH_SIZE)

    # Current Q(s,a)
    q_values = q_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)

    # Target Q
    with torch.no_grad():
        max_next_q = target_net(next_states).max(1)[0]
        target_q = rewards + GAMMA * (1 - dones) * max_next_q

    loss = nn.MSELoss()(q_values, target_q)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %%
# ======================
# Soft Update
# ======================
def soft_update(target_net, q_net, tau):
    for target_param, param in zip(target_net.parameters(), q_net.parameters()):
        target_param.data.copy_(
            tau * param.data + (1 - tau) * target_param.data
        )

# %%
# ======================
# Main Training Loop
# ======================
env = gym.make(ENV_NAME)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

q_net = QNetwork(state_dim, action_dim).to(device)
target_net = QNetwork(state_dim, action_dim).to(device)
target_net.load_state_dict(q_net.state_dict())

optimizer = optim.Adam(q_net.parameters(), lr=LR)
replay_buffer = ReplayBuffer(BUFFER_SIZE)

epsilon = EPS_START
scores = []

for episode in range(NUM_EPISODES):
    state, _ = env.reset()
    episode_reward = 0

    for step in range(MAX_STEPS):
        action = select_action(state, q_net, epsilon, action_dim)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        replay_buffer.add(state, action, reward, next_state, done)
        state = next_state
        episode_reward += reward

        if len(replay_buffer) >= MIN_REPLAY_SIZE:
            train_step(q_net, target_net, optimizer, replay_buffer)
            soft_update(target_net, q_net, TAU)

        if done:
            break

    epsilon = max(EPS_END, epsilon * EPS_DECAY)
    scores.append(episode_reward)

    print(f"Episode {episode:4d} | Reward: {episode_reward:7.2f} | Epsilon: {epsilon:.3f}")

env.close()
# Out:
# Episode    0 | Reward:  -58.22 | Epsilon: 0.995
# Episode    1 | Reward: -365.98 | Epsilon: 0.990
# Episode    2 | Reward: -335.13 | Epsilon: 0.985
# Episode    3 | Reward: -172.17 | Epsilon: 0.980
# Episode    4 | Reward: -244.25 | Epsilon: 0.975
# Episode    5 | Reward: -425.94 | Epsilon: 0.970
# Episode    6 | Reward:  -42.75 | Epsilon: 0.966
# Episode    7 | Reward: -284.03 | Epsilon: 0.961
# Episode    8 | Reward: -438.41 | Epsilon: 0.956
# Episode    9 | Reward: -120.16 | Epsilon: 0.951
# Episode   10 | Reward:  -40.61 | Epsilon: 0.946
# Episode   11 | Reward:  -45.53 | Epsilon: 0.942
# Episode   12 | Reward: -197.25 | Epsilon: 0.937
# Episode   13 | Reward: -342.74 | Epsilon: 0.932
# Episode   14 | Reward: -206.79 | Epsilon: 0.928
# Episode   15 | Reward: -169.66 | Epsilon: 0.923
# Episode   16 | Reward: -135.85 | Epsilon: 0.918
# Episode   17 | Reward:  -88.18 | Epsilon: 0.914
# Episode   18 | Reward:  -70.42 | Epsilon: 0.909
# Episode   19 | Reward:  -85.44 | Epsilon: 0.905
# Episode   20 | Reward: -221.11 | Epsilon: 0.900
# Episode   21 | Reward: -113.72 | Epsilon: 0.896
# Episode   22 | Reward: -131.58 | Epsilon: 0.891
# Episode   23 | Reward: -132.96 | Epsilon: 0.887
# Episode   24 | Reward: -128.83 | Epsilon: 0.882
# Episode   25 | Reward:  -84.83 | Epsilon: 0.878
# Episode   26 | Reward: -137.14 | Epsilon: 0.873
# Episode   27 | Reward: -324.07 | Epsilon: 0.869
# Episode   28 | Reward: -368.04 | Epsilon: 0.865
# Episode   29 | Reward:  -81.04 | Epsilon: 0.860
# Episode   30 | Reward:  -88.41 | Epsilon: 0.856
# Episode   31 | Reward: -272.26 | Epsilon: 0.852
# Episode   32 | Reward:  -49.87 | Epsilon: 0.848
# Episode   33 | Reward: -114.14 | Epsilon: 0.843
# Episode   34 | Reward: -264.46 | Epsilon: 0.839
# Episode   35 | Reward: -104.11 | Epsilon: 0.835
# Episode   36 | Reward: -103.90 | Epsilon: 0.831
# Episode   37 | Reward: -148.04 | Epsilon: 0.827
# Episode   38 | Reward: -103.49 | Epsilon: 0.822
# Episode   39 | Reward: -151.70 | Epsilon: 0.818
# Episode   40 | Reward:  -92.75 | Epsilon: 0.814
# Episode   41 | Reward:  -60.15 | Epsilon: 0.810
# Episode   42 | Reward:  -88.54 | Epsilon: 0.806
# Episode   43 | Reward:  -94.55 | Epsilon: 0.802
# Episode   44 | Reward: -163.20 | Epsilon: 0.798
# Episode   45 | Reward: -384.98 | Epsilon: 0.794
# Episode   46 | Reward:  -67.44 | Epsilon: 0.790
# Episode   47 | Reward: -114.19 | Epsilon: 0.786
# Episode   48 | Reward: -181.18 | Epsilon: 0.782
# Episode   49 | Reward:  -96.24 | Epsilon: 0.778
# Episode   50 | Reward:  -85.01 | Epsilon: 0.774
# Episode   51 | Reward: -123.29 | Epsilon: 0.771
# Episode   52 | Reward:  -86.86 | Epsilon: 0.767
# Episode   53 | Reward: -114.61 | Epsilon: 0.763
# Episode   54 | Reward: -100.91 | Epsilon: 0.759
# Episode   55 | Reward:  -66.18 | Epsilon: 0.755
# Episode   56 | Reward: -108.92 | Epsilon: 0.751
# Episode   57 | Reward: -123.17 | Epsilon: 0.748
# Episode   58 | Reward:  -85.58 | Epsilon: 0.744
# Episode   59 | Reward: -141.88 | Epsilon: 0.740
# Episode   60 | Reward: -273.25 | Epsilon: 0.737
# Episode   61 | Reward:  -85.66 | Epsilon: 0.733
# Episode   62 | Reward:  -50.77 | Epsilon: 0.729
# Episode   63 | Reward:  -95.71 | Epsilon: 0.726
# Episode   64 | Reward: -168.19 | Epsilon: 0.722
# Episode   65 | Reward:  -57.41 | Epsilon: 0.718
# Episode   66 | Reward:  -52.49 | Epsilon: 0.715
# Episode   67 | Reward:  -66.96 | Epsilon: 0.711
# Episode   68 | Reward:  -53.09 | Epsilon: 0.708
# Episode   69 | Reward:  -87.04 | Epsilon: 0.704
# Episode   70 | Reward:  -57.77 | Epsilon: 0.701
# Episode   71 | Reward:  -25.81 | Epsilon: 0.697
# Episode   72 | Reward:  -38.51 | Epsilon: 0.694
# Episode   73 | Reward:  -63.08 | Epsilon: 0.690
# Episode   74 | Reward: -122.04 | Epsilon: 0.687
# Episode   75 | Reward:  -25.50 | Epsilon: 0.683
# Episode   76 | Reward: -105.64 | Epsilon: 0.680
# Episode   77 | Reward:  -61.49 | Epsilon: 0.676
# Episode   78 | Reward: -107.15 | Epsilon: 0.673
# Episode   79 | Reward:  -40.27 | Epsilon: 0.670
# Episode   80 | Reward:  -87.94 | Epsilon: 0.666
# Episode   81 | Reward:  -73.28 | Epsilon: 0.663
# Episode   82 | Reward: -214.27 | Epsilon: 0.660
# Episode   83 | Reward:  -75.65 | Epsilon: 0.656
# Episode   84 | Reward:  -92.51 | Epsilon: 0.653
# Episode   85 | Reward:  -88.20 | Epsilon: 0.650
# Episode   86 | Reward:  -43.81 | Epsilon: 0.647
# Episode   87 | Reward:  -99.51 | Epsilon: 0.643
# Episode   88 | Reward:  -98.61 | Epsilon: 0.640
# Episode   89 | Reward: -135.30 | Epsilon: 0.637
# Episode   90 | Reward:  -66.32 | Epsilon: 0.634
# Episode   91 | Reward:  -79.21 | Epsilon: 0.631
# Episode   92 | Reward:  -72.31 | Epsilon: 0.627
# Episode   93 | Reward:  -83.52 | Epsilon: 0.624
# Episode   94 | Reward:  -27.31 | Epsilon: 0.621
# Episode   95 | Reward:  -68.34 | Epsilon: 0.618
# Episode   96 | Reward:  -44.32 | Epsilon: 0.615
# Episode   97 | Reward:  -63.80 | Epsilon: 0.612
# Episode   98 | Reward:  -37.84 | Epsilon: 0.609
# Episode   99 | Reward:  -95.57 | Epsilon: 0.606
# Episode  100 | Reward:  -98.02 | Epsilon: 0.603
# Episode  101 | Reward:    1.93 | Epsilon: 0.600
# Episode  102 | Reward:  -92.47 | Epsilon: 0.597
# Episode  103 | Reward:  -66.48 | Epsilon: 0.594
# Episode  104 | Reward:  -88.82 | Epsilon: 0.591
# Episode  105 | Reward:  -63.71 | Epsilon: 0.588
# Episode  106 | Reward:  -22.43 | Epsilon: 0.585
# Episode  107 | Reward:  -55.98 | Epsilon: 0.582
# Episode  108 | Reward:  -27.00 | Epsilon: 0.579
# Episode  109 | Reward:  -83.02 | Epsilon: 0.576
# Episode  110 | Reward:    7.36 | Epsilon: 0.573
# Episode  111 | Reward: -205.16 | Epsilon: 0.570
# Episode  112 | Reward:  -79.00 | Epsilon: 0.568
# Episode  113 | Reward:  -29.43 | Epsilon: 0.565
# Episode  114 | Reward:  -57.86 | Epsilon: 0.562
# Episode  115 | Reward:  -27.20 | Epsilon: 0.559
# Episode  116 | Reward: -101.55 | Epsilon: 0.556
# Episode  117 | Reward:  -42.78 | Epsilon: 0.554
# Episode  118 | Reward:  -81.24 | Epsilon: 0.551
# Episode  119 | Reward: -321.37 | Epsilon: 0.548
# Episode  120 | Reward:  -53.36 | Epsilon: 0.545
# Episode  121 | Reward:  -58.68 | Epsilon: 0.543
# Episode  122 | Reward:  -67.36 | Epsilon: 0.540
# Episode  123 | Reward: -176.75 | Epsilon: 0.537
# Episode  124 | Reward: -124.85 | Epsilon: 0.534
# Episode  125 | Reward: -108.65 | Epsilon: 0.532
# Episode  126 | Reward:  -89.15 | Epsilon: 0.529
# Episode  127 | Reward:  -38.74 | Epsilon: 0.526
# Episode  128 | Reward:   19.27 | Epsilon: 0.524
# Episode  129 | Reward:  -37.73 | Epsilon: 0.521
# Episode  130 | Reward:  -64.37 | Epsilon: 0.519
# Episode  131 | Reward:  -27.73 | Epsilon: 0.516
# Episode  132 | Reward:  -58.74 | Epsilon: 0.513
# Episode  133 | Reward:  -48.59 | Epsilon: 0.511
# Episode  134 | Reward:  -76.79 | Epsilon: 0.508
# Episode  135 | Reward:   15.28 | Epsilon: 0.506
# Episode  136 | Reward: -293.22 | Epsilon: 0.503
# Episode  137 | Reward:  -46.37 | Epsilon: 0.501
# Episode  138 | Reward:  -31.23 | Epsilon: 0.498
# Episode  139 | Reward:   14.78 | Epsilon: 0.496
# Episode  140 | Reward:   27.46 | Epsilon: 0.493
# Episode  141 | Reward: -195.46 | Epsilon: 0.491
# Episode  142 | Reward:  -34.08 | Epsilon: 0.488
# Episode  143 | Reward:  -47.89 | Epsilon: 0.486
# Episode  144 | Reward:  -38.65 | Epsilon: 0.483
# Episode  145 | Reward:  -61.42 | Epsilon: 0.481
# Episode  146 | Reward:  -16.85 | Epsilon: 0.479
# Episode  147 | Reward:    0.47 | Epsilon: 0.476
# Episode  148 | Reward: -195.64 | Epsilon: 0.474
# Episode  149 | Reward:  -94.88 | Epsilon: 0.471
# Episode  150 | Reward:   -5.66 | Epsilon: 0.469
# Episode  151 | Reward:  -49.20 | Epsilon: 0.467
# Episode  152 | Reward:  -60.38 | Epsilon: 0.464
# Episode  153 | Reward:  -28.24 | Epsilon: 0.462
# Episode  154 | Reward:  -60.58 | Epsilon: 0.460
# Episode  155 | Reward: -317.53 | Epsilon: 0.458
# Episode  156 | Reward:  -35.68 | Epsilon: 0.455
# Episode  157 | Reward:  -61.10 | Epsilon: 0.453
# Episode  158 | Reward:    4.89 | Epsilon: 0.451
# Episode  159 | Reward: -322.42 | Epsilon: 0.448
# Episode  160 | Reward:   -9.78 | Epsilon: 0.446
# Episode  161 | Reward: -196.64 | Epsilon: 0.444
# Episode  162 | Reward: -434.80 | Epsilon: 0.442
# Episode  163 | Reward: -139.05 | Epsilon: 0.440
# Episode  164 | Reward:   33.77 | Epsilon: 0.437
# Episode  165 | Reward:    9.11 | Epsilon: 0.435
# Episode  166 | Reward:  -77.26 | Epsilon: 0.433
# Episode  167 | Reward: -127.50 | Epsilon: 0.431
# Episode  168 | Reward: -161.96 | Epsilon: 0.429
# Episode  169 | Reward:  -25.63 | Epsilon: 0.427
# Episode  170 | Reward:  -31.13 | Epsilon: 0.424
# Episode  171 | Reward:    3.94 | Epsilon: 0.422
# Episode  172 | Reward: -278.99 | Epsilon: 0.420
# Episode  173 | Reward:   36.89 | Epsilon: 0.418
# Episode  174 | Reward:    3.97 | Epsilon: 0.416
# Episode  175 | Reward:   69.12 | Epsilon: 0.414
# Episode  176 | Reward:   35.34 | Epsilon: 0.412
# Episode  177 | Reward:   10.34 | Epsilon: 0.410
# Episode  178 | Reward:  -24.42 | Epsilon: 0.408
# Episode  179 | Reward:   21.84 | Epsilon: 0.406
# Episode  180 | Reward:  -63.14 | Epsilon: 0.404
# Episode  181 | Reward:    0.89 | Epsilon: 0.402
# Episode  182 | Reward: -168.98 | Epsilon: 0.400
# Episode  183 | Reward: -127.21 | Epsilon: 0.398
# Episode  184 | Reward:  -13.65 | Epsilon: 0.396
# Episode  185 | Reward:   -3.35 | Epsilon: 0.394
# Episode  186 | Reward:  -17.52 | Epsilon: 0.392
# Episode  187 | Reward:  -67.67 | Epsilon: 0.390
# Episode  188 | Reward:   -8.01 | Epsilon: 0.388
# Episode  189 | Reward:  -54.40 | Epsilon: 0.386
# Episode  190 | Reward:   13.99 | Epsilon: 0.384
# Episode  191 | Reward:   51.94 | Epsilon: 0.382
# Episode  192 | Reward:  -50.53 | Epsilon: 0.380
# Episode  193 | Reward:   82.66 | Epsilon: 0.378
# Episode  194 | Reward:    9.57 | Epsilon: 0.376
# Episode  195 | Reward:  -83.39 | Epsilon: 0.374
# Episode  196 | Reward:    8.57 | Epsilon: 0.373
# Episode  197 | Reward:  114.73 | Epsilon: 0.371
# Episode  198 | Reward: -103.11 | Epsilon: 0.369
# Episode  199 | Reward:   42.42 | Epsilon: 0.367
